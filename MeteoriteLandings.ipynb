# %%
import pandas as pd

# %%
df = pd.read_csv("MeteoriteLandings.csv")

# %%
df.head()
# Out:
#        name   id nametype     recclass mass (g)  fall    year    reclat  \
# 0    Aachen    1    Valid           L5       21  Fell  1880.0  50.77500
# 1    Aarhus    2    Valid           H6      720  Fell  1951.0  56.18333
# 2      Abee    6    Valid          EH4   107000  Fell  1952.0  54.21667
# 3  Acapulco   10    Valid  Acapulcoite     1914  Fell  1976.0  16.88333
# 4   Achiras  370    Valid           L6      780  Fell  1902.0 -33.16667
#
#     reclong           GeoLocation
# 0   6.08333     (50.775, 6.08333)
# 1  10.23333  (56.18333, 10.23333)
# 2      -113    (54.21667, -113.0)
# 3     -99.9     (16.88333, -99.9)
# 4    -64.95   (-33.16667, -64.95)

# %%
df.shape
# Out:
# (45716, 10)

# %%
df.describe()
# Out:
#                year        reclat
# count  45425.000000  38401.000000
# mean    1990.336880    -39.144379
# std       60.480837     46.362982
# min      -83.500000   -105.100000
# 25%     1987.000000    -76.714270
# 50%     1998.000000    -71.500000
# 75%     2003.000000      0.000000
# max     2101.000000    165.000000

# %%
import pandas_profiling
from pandas_profiling.utils.cache import cache_file

# %%
df["source"] = "NASA"

# %%
df
# Out:
#              name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4   107000   Fell
# 3        Acapulco     10    Valid           Acapulcoite     1914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6     2167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#          year    reclat     reclong             GeoLocation source
# ...

# %%
import numpy as np

# %%
df["boolen"] = np.random.choice([True, False], df.shape[0])

# %%
df
# Out:
#              name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4   107000   Fell
# 3        Acapulco     10    Valid           Acapulcoite     1914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6     2167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#          year    reclat     reclong             GeoLocation source  boolen
# ...

# %%
df["mixed"] = np.random.choice([1, "A"], df.shape[0])

# %%
df
# Out:
#              name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4   107000   Fell
# 3        Acapulco     10    Valid           Acapulcoite     1914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6     2167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#          year    reclat     reclong             GeoLocation source  boolen  \
# ...

# %%
df["reclat_city"] = df["reclat"] + np.random.normal(scale=5, size=(len(df)))

# %%
df
# Out:
#              name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4   107000   Fell
# 3        Acapulco     10    Valid           Acapulcoite     1914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6     2167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#          year    reclat     reclong             GeoLocation source  boolen  \
# ...

# %%
duplicate_to_add = pd.DataFrame(df.iloc[0:10])
duplicate_to_add[u'name'] = duplicate_to_add[u'name'] + " copy"

# %%
df
# Out:
#              name     id nametype              recclass mass (g)   fall  \
# 0          Aachen      1    Valid                    L5       21   Fell
# 1          Aarhus      2    Valid                    H6      720   Fell
# 2            Abee      6    Valid                   EH4   107000   Fell
# 3        Acapulco     10    Valid           Acapulcoite     1914   Fell
# 4         Achiras    370    Valid                    L6      780   Fell
# ...           ...    ...      ...                   ...      ...    ...
# 45711  Zillah 002  31356    Valid               Eucrite      172  Found
# 45712      Zinder  30409    Valid  Pallasite, ungrouped       46  Found
# 45713        Zlin  30410    Valid                    H4      3.3  Found
# 45714   Zubkovsky  31357    Valid                    L6     2167  Found
# 45715  Zulu Queen  30414    Valid                  L3.7      200  Found
#
#          year    reclat     reclong             GeoLocation source  boolen  \
# ...

# %%
df = df.append(duplicate_to_add, ignore_index=True)
# Out:
# C:\Users\rocio\AppData\Local\Temp\ipykernel_16824\659634668.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(duplicate_to_add, ignore_index=True)

# %%
df
# Out:
#                            name   id nametype     recclass mass (g)  fall  \
# 0                        Aachen    1    Valid           L5       21  Fell
# 1                        Aarhus    2    Valid           H6      720  Fell
# 2                          Abee    6    Valid          EH4   107000  Fell
# 3                      Acapulco   10    Valid  Acapulcoite     1914  Fell
# 4                       Achiras  370    Valid           L6      780  Fell
# ...                         ...  ...      ...          ...      ...   ...
# 45721             Adhi Kot copy  379    Valid          EH4     4239  Fell
# 45722  Adzhi-Bogdo (stone) copy  390    Valid        LL3-6      910  Fell
# 45723                 Agen copy  392    Valid           H5    30000  Fell
# 45724               Aguada copy  398    Valid           L6     1620  Fell
# 45725        Aguila Blanca copy  417    Valid            L     1440  Fell
#
#          year    reclat    reclong           GeoLocation source  boolen mixed  \
# ...

# %% [markdown]
# Reporte en linea sin guardar el objeto

# %%
from pandas_profiling import ProfileReport
prof = ProfileReport(df)
prof.to_file(output_file='output.html')
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In [36], line 1
# ----> 1 from pandas_profiling import ProfileReport
#       2 prof = ProfileReport(df)
#       3 prof.to_file(output_file='output.html')
#
# File c:\Users\rocio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas_profiling\__init__.py:6
#       1 """Main module of pandas-profiling.
#       2
#       3 .. include:: ../../README.md
#       4 """
# ----> 6 from pandas_profiling.controller import pandas_decorator
#       7 from pandas_profiling.profile_report import ProfileReport
#       8 from pandas_profiling.version import __version__
#
# File c:\Users\rocio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas_profiling\controller\pandas_decorator.py:4
#       1 """This file add the decorator on the DataFrame object."""
#       2 from pandas import DataFrame
# ...

# %%
report = df.profile_report(sort='None', html={'style': {'full_width': True}} )
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In [34], line 1
# ----> 1 report = df.profile_report(sort= 'None', html={'style': {'full_width': True}} )
#
# File c:\Users\rocio\AppData\Local\Programs\Python\Python311\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'profile_report'
